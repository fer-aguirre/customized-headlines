# %% [markdown]
# ### Imports

# %%
import re
import pandas as pd
import numpy as np
import openai
import pinecone
import configparser

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('../data/processed/embeddings.csv', dtype={'index': 'string'})
df['embedding_ada'] = np.array(df.embedding_ada.apply(eval))
df.head(3)
# Out:
#                                                  url index  resolved  status  \
# 0  https://unamglobal.unam.mx/comunidades-indigen...    46       NaN     200
# 1  https://www.milenio.com/negocios/larry-rubin-t...     0       NaN     200
# 2  https://unamglobal.unam.mx/el-giro-y-el-miedo-...    47       NaN     200
#
#                  datetime_utc  error                               filename  \
# 0  2023-04-02T15:25:07.419616    NaN  16dd649be430106e823d0f6ad1d7c638.html
# 1  2023-04-02T15:25:07.112501    NaN  bf6c8a5bb799314dcdb37c7085c38a81.html
# 2  2023-04-02T15:25:09.140811    NaN  99ef9ca8a1832cd7de1d7cf6cb6d54c8.html
#
#     mimetype encoding  extract_error  ... comments              author  \
# 0  text/html    utf-8            NaN  ...      NaN         Beto Torres
# 1  text/html    utf-8            NaN  ...      NaN  Eduardo de la Rosa
# 2  text/html    utf-8            NaN  ...      NaN         Beto Torres
#
#      categories                                               tags  \
# 0  BLOG|Opinión                          blog|opinión|blog|opinión
# 1      Negocios  American Society of Mexico|tatiana clouthier|a...
# 2  BLOG|Opinión                          blog|opinión|blog|opinión
#
#          date       sitename  \
# 0  2021-02-09    UNAM Global
# 1  2022-10-06  Grupo Milenio
# 2  2021-05-19    UNAM Global
#
#                                        clean_content  \
# 0  La pandemia derivada de la COVID-19 ha signifi...
# 1  El presidente de la American Society of Mexico...
# 2  Hace unos dias se celebro en Turin la centesim...
#
#                                             combined n_tokens  \
# 0  Titulo: 0     Comunidades indígenas urbanas en...      352
# 1  Titulo: 0     Comunidades indígenas urbanas en...      352
# 2  Titulo: 0     Comunidades indígenas urbanas en...      352
#
#                                        embedding_ada
# 0  [0.0006488185026682913, -0.0057064443826675415...
# 1  [0.0006488185026682913, -0.0057064443826675415...
# 2  [0.0006488185026682913, -0.0057064443826675415...
#
# [3 rows x 24 columns]

# %%
# Remove text on string after '|' symbol
df['clean_title'] = df['title'].apply(lambda x : re.sub(r'\s\|.*', '', x))

# %%
embeds = df['embedding_ada']

# %% [markdown]
# ### Set up Pinecone API key

# %%
# Create a parser object and disable interpolation
parser = configparser.ConfigParser(interpolation=None)

# Read data from 'config.ini' file
parser.read("../config.ini")

# Access sections from the configuration file
parser.sections()

# Get 'key' from pinecone section
api_key = parser.get('pinecone', 'key')

# %% [markdown]
# ### Store vector embeddings with [`Pinecone`](https://www.pinecone.io/)

# %%
index_name = 'semantic-search-openai'

# initialize connection to pinecone
pinecone.init(
    api_key=api_key,
    environment="asia-southeast1-gcp"  # find next to api key in console
)

# %%
if index_name not in pinecone.list_indexes():
    pinecone.create_index(index_name, dimension=len(embeds[0]), metric="cosine")

# %%
# connect to index
index = pinecone.Index(index_name)

# %%
meta = [{'content': line} for line in zip(df['clean_title'], df['clean_content'])]
to_upsert = zip(df['index'], embeds, meta)
# upsert to Pinecone
index.upsert(vectors=list(to_upsert))
# Out:
# {'upserted_count': 100}

# %% [markdown]
# ### Set up OpenAI API key

# %%
# Create a parser object and disable interpolation
parser = configparser.ConfigParser(interpolation=None)

# Read data from 'config.ini' file
parser.read("../config.ini")

# Access sections from the configuration file
parser.sections()

# Get 'bearer_token' from twitter section
api_key = parser.get('openai', 'key')

# Set up OpenAI API key
openai.api_key = api_key

# %%
query1 = "Arte"
query2 = "Cultura"

# %%
emb_q1 = openai.Embedding.create(input=query1, engine="text-embedding-ada-002")['data'][0]['embedding']
emb_q2= openai.Embedding.create(input=query2, engine="text-embedding-ada-002")['data'][0]['embedding']

# %%
user_model = np.mean([emb_q1, emb_q2], axis=0).tolist()

# %%
res = index.query([user_model], top_k=3, include_metadata=True)

# %%
res
# Out:
# {'matches': [{'id': '92',
#               'metadata': {'content': ['IKEA “celebra” a Latinoamérica con '
#                                        'lanzamiento de colección ÖMSESIDIG',
#                                        '- IKEA lanzo OMSESIDIG, su primera '
#                                        'coleccion de productos creada en '
#                                        'colaboracion con artistas '
#                                        'latinoamericanos. - En espanol '
#                                        'significa “mutuo” y explora las '
#                                        'celebraciones, tradiciones de reunion '
#                                        'y cultura en America Latina. - '
#                                        'Business Insider Mexico platico con '
#                                        'Friso Wiersma, disenador de IKEA of '
#                                        'Sweden que dirigio OMSESIDIG, sobre el '
#                                        'proceso para elaborar sus 30 '
#                                        'productos. - ¿Ya conoces nuestra '
#                                        'cuenta en Instagram? Siguenos. Antes '
#                                        'de abrir su primera tienda fisica en '
#                                        'Mexico, IKEA ya estaba trabajando en '
#                                        'una coleccion creada por artistas '
#                                        'latinoamericanos y que seria vendida '
#                                        'en sus mas de 60 mercados del mundo. '
#                                        'La semana pasada, la marca sueca de '
#                                        'muebles y productos del hogar lanzo '
#                                        'OMSESIDIG, que en espanol significa '
#                                        '“mutuo”; la coleccion explora las '
#                                        'celebraciones, tradiciones de reunion '
#                                        'y cultura en Latinoamerica. OMSESIDIG '
#                                        'reune a nueve creativos de America '
#                                        'Latina y esta conformada por 30 '
#                                        'productos que incluyen cristaleria y '
#                                        'vajillas, adornos, portavelas, '
#                                        'taburetes, textiles, fundas de '
#                                        'cojines, bolsas para hieleras, dos '
#                                        'versiones unicas de su iconica bolsa '
#                                        'FRAKTA y tres fundas para su bocina '
#                                        'inteligente SYMFONISK. En entrevista '
#                                        'con Business Insider Mexico, Friso '
#                                        'Wiersma, disenador de IKEA of Sweden, '
#                                        'explico que el punto de partida para '
#                                        'esta coleccion fue la curiosidad que '
#                                        'la marca tiene por saber como vive la '
#                                        'gente en otras partes del mundo. '
#                                        '“Tenemos mucho conocimiento sobre la '
#                                        'vida en el hogar, pero eso se basa '
#                                        'principalmente del lugar de donde '
#                                        'somos. Siempre tenemos curiosidad por '
#                                        'saber como vive la gente en nuevos '
#                                        'mercados”, dijo. El siguiente paso '
#                                        'para crear OMSESIDIG fue pensar que '
#                                        'tipos de formas se queria tener. Sin '
#                                        'embargo, en ese momento, inicio la '
#                                        'pandemia del Covid-19, lo que retraso '
#                                        'su proceso de la coleccion, que en '
#                                        'promedio toma entre dos o tres anos. '
#                                        '“Las cosas se volvieron complicadas, '
#                                        'pero teniamos ideas de que queriamos '
#                                        'hacer. No queriamos cancelarlo porque '
#                                        'nos encanta colaborar y queriamos '
#                                        'encontrar la manera de que si '
#                                        'sucediera”, aseguro Wiersma. A pesar '
#                                        'de la pandemia, IKEA abrio su primera '
#                                        'tienda fisica en Mexico en abril de '
#                                        '2021, y casi dos anos mas tarde, '
#                                        'OMSESIDIG vio la luz. OMSESIDIG se '
#                                        'inspiro en las historias de sus '
#                                        'disenadores Con cinco anos trabajando '
#                                        'como disenador de IKEA of Sweden, '
#                                        'Wiersma fue el responsable de '
#                                        'coordinar la creacion de OMSESIDIG. '
#                                        'Aunque el no fue el responsable de '
#                                        'seleccionar a los disenadores '
#                                        'latinoamericanos que formaron parte de '
#                                        'ella, explico a Business Insider '
#                                        'Mexico que la marca busca tener una '
#                                        'variedad de artistas especializados en '
#                                        'diferentes disciplinas. Es por ello '
#                                        'que en esta coleccion tenemos a la '
#                                        'mexicana Liliana Ovalle, disenadora de '
#                                        'productos; Trini Guzman, muralista y '
#                                        'artista multidisciplinaria chilena; y '
#                                        'Agustin Nicolas Rivero, disenador de '
#                                        'moda de Colombia. En OMSESIDIG tambien '
#                                        'colaboraron: - Diana Ordonez, artista '
#                                        'colombiana - Abel Carcamo Segovia, '
#                                        'disenador de productos chileno - '
#                                        'Marisol Centeno, disenadora textil '
#                                        'mexicana - Alvaro Clavijo, chef '
#                                        'colombiano - Catalina Zarhi, ceramista '
#                                        'chilena - Felipe Assadi, arquitecto '
#                                        'chileno De acuerdo con Wiersma, el '
#                                        'enfoque que se trabajo con los nueve '
#                                        'fue vanguardista; se les pidio que '
#                                        'pensaran directamente sobre el '
#                                        'producto que querian disenar a partir '
#                                        'de una historia sobre lo que significa '
#                                        'para ellos celebrar. “Tal vez una '
#                                        'historia de ahora, tal vez del '
#                                        'pasado”, aseguro el disenador sueco. '
#                                        '“Vinieron con hermosas historias '
#                                        'personales y eso fue muy agradable '
#                                        'para nosotros. Estaba vivo”. '
#                                        '“Compartieron las historias con fotos, '
#                                        'dibujos y hasta recetas. A partir de '
#                                        'ahi dijimos: ¡ok, vamos a deconstruir '
#                                        'la historia. ¿Que aspectos te inspiran '
#                                        'de ella?’” Por ejemplo, Ovalle '
#                                        'compartio que su adolescencia estuvo '
#                                        'muy marcada por recorrer las calles de '
#                                        'la Ciudad de Mexico, la comida que se '
#                                        'podia comprar en ellas y la presencia '
#                                        'del limon en esta. Como resultado, la '
#                                        'mexicana creo unos tazones de vidrio '
#                                        'con forma y del mismo color que el '
#                                        'limon. Una vez que cada uno de los '
#                                        'artistas tuvo claro lo que queria '
#                                        'hacer, Wiersma los ayudo para que los '
#                                        'productos contaran con caracteristicas '
#                                        'especificas que IKEA requiere para su '
#                                        'produccion, como que sean seguros a la '
#                                        'hora de producirse, sostenibles y '
#                                        'puedan fabricarse y enviarse a todo el '
#                                        'mundo. Colores latinoamericanos, '
#                                        'nombres suecos Regularmente, IKEA '
#                                        'apuesta porque sus productos tengan '
#                                        'colores neutros con algunos toques que '
#                                        'resaltan o llaman la atencion. '
#                                        'OMSESIDIG es diferente, ya que al '
#                                        'representar a Latinoamerica, esta '
#                                        'llena de diferentes colores. No '
#                                        'obstante, segun Wiersma, esto no fue a '
#                                        'proposito al momento de crear la '
#                                        'coleccion y, de hecho, no se les '
#                                        'asigno una paleta de color especifica. '
#                                        '“Queria confiar en el proceso. Lo que '
#                                        'dijimos fue: ‘Realmente vamos a '
#                                        'mostrar y celebrar las diferencias '
#                                        'entre los paises de Latinoamerica’. '
#                                        'Asi que llevamos a los artistas y '
#                                        'disenadores a hacer lo suyo”. '
#                                        '“Confiabamos en que se unirian. ¡Me '
#                                        'encanto! Viendo la coleccion, ahora '
#                                        'sentimos que ocurrio algo de magia”, '
#                                        'anadio. Algo que la coleccion no pudo '
#                                        'quitarse fue que su nombre estuviera '
#                                        'en sueco, al igual que el resto de los '
#                                        'productos de IKEA. Wiersma conto a '
#                                        'Business Insider Mexico que esto es '
#                                        'parte de una tradicion de la compania '
#                                        'que fue instaurada por su fundador, '
#                                        'Ingvar Kamprad. “El al principio daba '
#                                        'numeros a los productos especificos, '
#                                        'pero luego no podia recordarlos. '
#                                        'Entonces, primero comenzo a poner a '
#                                        'los productos nombres de amigos, de '
#                                        'pueblos y, en cierto momento, se '
#                                        'convirtio en una tradicion de IKEA”, '
#                                        'relato. “Es algo de lo que estamos muy '
#                                        'orgullosos. Estamos orgullosos de '
#                                        'nuestra herencia y de ser de Suecia”, '
#                                        'agrego. OMSESIDIG ya se encuentra '
#                                        'disponible en IKEA Mexico y sus 30 '
#                                        'productos son edicion limitada. AHORA '
#                                        'LEE: Los “cleanfluencers” luchan '
#                                        'contra la suciedad en las redes '
#                                        'sociales TAMBIEN LEE: Vekalife: la '
#                                        'influencer que invita a limpiar el '
#                                        'hogar para limpiar la mente']},
#               'score': 0.782266796,
#               'values': []},
#              {'id': '47',
#               'metadata': {'content': ['El Giro y el miedo a la bici',
#                                        'Hace unos dias se celebro en Turin la '
#                                        'centesima cuarta edicion del Giro de '
#                                        'Italia, la ciudad piamontesa fue la '
#                                        'primera de las 21 etapas que componen '
#                                        'la competencia que se lleva a cabo en '
#                                        'el mes de mayo desde 1909 en su '
#                                        'version masculina. El sabado fui '
#                                        'testigo de la tercera partida mas '
#                                        'veloz en la historia de la '
#                                        'competencia, gano en casa la “maglia '
#                                        'rosa” el piamontes Filippo Ganna, con '
#                                        'una media de 58.748 km/h con la que '
#                                        'corrio los 8,6 kilometros del circuito '
#                                        'que partia de plaza Castello. Fue una '
#                                        'suerte que despues de una timida y '
#                                        'nubosa primavera, el sabado pudieramos '
#                                        'disfrutar de un dia soleado que '
#                                        'invitaba a la gente a participar en un '
#                                        'evento tanto esperado por la comunidad '
#                                        'de ciclistas. Admito que durante los '
#                                        'anos que vivi en la CDMX, la bicicleta '
#                                        'no formo parte de mis principales '
#                                        'medios de transporte, es mas, tengo en '
#                                        'alta estima a quienes a pesar de todos '
#                                        'los riesgos que puede representar la '
#                                        'bici en una ciudad como la nuestra, la '
#                                        'usan cotidianamente. Tenia tanto miedo '
#                                        'de usarla, que aunque pague la '
#                                        'suscripcion al servicio de sharing de '
#                                        'la ciudad, lo use apenas un par de '
#                                        'veces… la conocia desde siempre, la '
#                                        'usaban tios, mi padre, mi hermano, ex '
#                                        'parejas, incluso cuando mi marido '
#                                        'empezo a aficionarse pense que se '
#                                        'trataba de algun tipo de maldicion. '
#                                        'Con la pandemia, muchos buscamos '
#                                        'medios alternativos al transporte '
#                                        'publico para poder movernos. Empece a '
#                                        'caminar mas, pero mi naturaleza '
#                                        'retardataria pronto me mostro las '
#                                        'desventajas de este sistema. Pense en '
#                                        'la cuestion no resuelta de la bici y '
#                                        'busque una que se acomodara a mis '
#                                        'necesidades, despues de batallar con '
#                                        'la bicicleta de montana y su '
#                                        'estructura que no me resultaba del '
#                                        'todo amigable, encontre una “bici de '
#                                        'ciudad” que me hizo sentir por primera '
#                                        'vez duena de la calle. Desde entonces '
#                                        'solo podia contar las ventajas de usar '
#                                        'la bici como principal medio de '
#                                        'transporte. No extrano que en el metro '
#                                        'o el autobus el cubrebocas me empane '
#                                        'los lentes o buscar estacionamiento '
#                                        'cuando vamos en auto. Durante este '
#                                        'periodo particular, donde socializar '
#                                        'es tan dificil, la bicicleta se ha '
#                                        'convertido tambien en un pretexto para '
#                                        'hacer ejercicio y encontrarte '
#                                        'ciclistas buena onda en el camino. '
#                                        'Despues de la salida de los primeros '
#                                        'ciclistas del Giro, junto con mi '
#                                        'pareja aproveche para pedalear en los '
#                                        'espacios verdes de la ciudad. Con el '
#                                        'extasis de la competencia, nos '
#                                        'encontramos varios grupos de ciclistas '
#                                        'amateur en uniformes y bicis '
#                                        'profesionales, otros con bicis '
#                                        'rescatadas del fierro viejo, '
#                                        'triciclos, monopatines, … el '
#                                        'movimiento era la orden del dia. Cerca '
#                                        'del final de la competencia, '
#                                        'regresabamos a casa al lado del rio Po '
#                                        'sobre un carril para ciclistas. Vimos '
#                                        'que un nino de unos seis anos venia '
#                                        'hacia nosotros en sentido contrario a '
#                                        'toda velocidad y como pudimos, '
#                                        'frenamos, pero el pequeno derrapo y '
#                                        'cayo. No se como se lleno de hojarasca '
#                                        'y tierra hasta la espalda, escuche que '
#                                        'su padre venia gritando a lo lejos en '
#                                        'bicicleta. Cuando llego, se acerco '
#                                        'para gritarle, que debia tener mas '
#                                        'cuidado, que apenas habian salido de '
#                                        'casa. Ni siquiera tomaba aire. El '
#                                        'nino, tirado en el piso. Estaba entre '
#                                        'los gritos del don que me ponian '
#                                        'nerviosa y las ganas de levantar al '
#                                        'nino, decirle que no era su culpa, que '
#                                        'cuando uno rueda, esas cosas pasan. '
#                                        'Levante la pequena bici, se la di al '
#                                        'padre, que solo hizo pausa en el '
#                                        'regano para darme las gracias, despues '
#                                        'levante con mucho cuidado al nino, '
#                                        'mientras le preguntaba si estaba bien, '
#                                        'lo tome un poco apenada, pense que no '
#                                        'debia tocarlo una extrana, pero las '
#                                        'palabras de su padre parecian pegarlo '
#                                        'al suelo. Busque su mirada y con '
#                                        'sorpresa vi que estaba enojado, ni una '
#                                        'lagrima, afortunadamente estaba bien. '
#                                        'Seguimos nuestro camino, coincidimos '
#                                        'con el final de la etapa de ese dia '
#                                        'del Giro, y vimos varios de los autos '
#                                        'que cargan las bicis y camaras que '
#                                        'siguen a los ciclistas, como sorpresa '
#                                        'extra del dia, cruzamos camino con el '
#                                        'numero 168 de la competencia sobre '
#                                        'avenida Reina Margarita y le dije a '
#                                        'Tono: “siguelo”, mientras yo me '
#                                        'quedaba inevitablemente atras. Despues '
#                                        'de una llanta ponchada, llegamos por '
#                                        'fin a casa. Esa noche despues de la '
#                                        'cena segui pensando en la mirada de '
#                                        'enojo del nino. Comprendi que el enojo '
#                                        'es una emocion que (a muchos de '
#                                        'nosotros) nos ensenan los adultos para '
#                                        'lidiar con nuestras emociones '
#                                        'complicadas, vergonzosas y primitivas. '
#                                        'Desee que el pequeno pudiera algun dia '
#                                        'vivir sus emociones sin filtros ni '
#                                        'estereotipos, llorar si hace falta, '
#                                        'sentir miedo, verguenza, dejar de ser '
#                                        'el espejo de los adultos que nos '
#                                        'rodearon en los anos tiernos, '
#                                        'sentirnos, para no destruirnos. Sentir '
#                                        'la misma libertad y agilidad que me '
#                                        'tomo tanto tiempo experimentar sin '
#                                        'miedo a caerme, porque cuando uno '
#                                        'rueda, esas cosas pasan. *Egresada de '
#                                        'la Facultad de Filosofia y Letras de '
#                                        'la UNAM']},
#               'score': 0.782223344,
#               'values': []},
#              {'id': '2',
#               'metadata': {'content': ['Astronauta mexicana llevó cenizas de '
#                                        'su abuelo al espacio',
#                                        'La ingeniera electrica y astronauta '
#                                        'mexicana, Katya Echazarreta, aseguro '
#                                        'que cuando viajo al espacio, ese dia '
#                                        'fueron dos mexicanos los que '
#                                        'participaron en la quinta mision '
#                                        'tripulada de Blue Origin, debido a que '
#                                        'llevo parte de las cenizas de su '
#                                        'abuelo, quien murio el ano pasado. A '
#                                        'traves de su cuenta de TikTok, la '
#                                        'joven astronauta compartio un video '
#                                        'donde recuerda que su abuelo fallecio '
#                                        'en 2021 y no pudo enterarse de que '
#                                        'ella iria al espacio, pero senalo que '
#                                        'el siempre le decia que, "¡Cuando '
#                                        'subas que no se te olvide saludarme!". '
#                                        'A Echazarreta se le ocurrio algo '
#                                        'mejor, y dijo que se llevo algunas de '
#                                        'las cenizas de su abuelo, por eso, '
#                                        'afirmo que "dos mexicanos fueron al '
#                                        'espacio ese dia". "He estado en las '
#                                        'noticias, revistas, he conocido a '
#                                        'alguna de las personas mas importantes '
#                                        'y he hablado con miles de personas, '
#                                        'pero no fui la unica mexicana que fue '
#                                        'al espacio ese dia". $MENTION$.mx  '
#                                        '$HASHTAG$ $HASHTAG$ $HASHTAG$ '
#                                        '$HASHTAG$ $HASHTAG$ $HASHTAG$ '
#                                        '$HASHTAG$ $HASHTAG$ $HASHTAG$ '
#                                        '$HASHTAG$ $HASHTAG$ $HASHTAG$ '
#                                        '$HASHTAG$♬ original sound - carla Esta '
#                                        'licenciada en ingenieria electrica, '
#                                        'que trabajo casi cuatro anos en un '
#                                        'laboratorio de la NASA, fue '
#                                        'seleccionada entre mas de 7 mil '
#                                        'solicitantes de mas de 100 paises y '
#                                        'representara a las mujeres y minorias '
#                                        'interesadas en la ciencia, la '
#                                        'tecnologia, la ingenieria y las '
#                                        'matematicas. Ademas, Katya Echazarreta '
#                                        'aprovecho la ocasion para dedicar su '
#                                        'participacion en la quinta mision '
#                                        'tripulada de Blue Origin a su pais y a '
#                                        'toda la comunidad latinoamericana. '
#                                        'LG']},
#               'score': 0.782223344,
#               'values': []}],
#  'namespace': ''}

# %%
for match in res['matches']:
    print(f"index: {match['id']}, score: {match['score']:.2f}, content: {match['metadata']['content'][0]}")
# Out:
# index: 92, score: 0.78, content: IKEA “celebra” a Latinoamérica con lanzamiento de colección ÖMSESIDIG
# index: 47, score: 0.78, content: El Giro y el miedo a la bici
# index: 2, score: 0.78, content: Astronauta mexicana llevó cenizas de su abuelo al espacio
